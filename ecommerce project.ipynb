# %%
import pandas as pd

# %%
data = pd.read_csv('Ecommerce Purchases')

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 3807        48419 James Villages\nCharlesside, MN 05281  16 Od       PM
# 3808       41420 Morgan Square\nNew Sylviaton, NH 91906  04 lg       AM
# 3809     308 Dixon Fords Suite 923\nNicoleton, MH 45145  52 YN       AM
# 3810  7016 Richard Center Apt. 216\nNew Paulburgh, C...  53 WU       AM
# 3811  625 Mclaughlin Inlet Apt. 375\nSouth Ruben, CO...  94 he       PM
#
#                                            Browser Info  \
# ...

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            1
# Purchase Price      1
# dtype: int64

# %%
data.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.size()
#
# TypeError: 'int' object is not callable

# %%
data.size
# Out:
# 53368

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (3812, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3812 entries, 0 to 3811
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           3812 non-null   object
#  1   Lot               3812 non-null   object
#  2   AM or PM          3812 non-null   object
#  3   Browser Info      3812 non-null   object
#  4   Company           3812 non-null   object
#  5   Credit Card       3812 non-null   int64
#  6   CC Exp Date       3812 non-null   object
#  7   CC Security Code  3812 non-null   int64
#  8   CC Provider       3812 non-null   object
#  9   Email             3812 non-null   object
#  10  Job               3812 non-null   object
#  11  IP Address        3812 non-null   object
#  12  Language          3811 non-null   object
#  13  Purchase Price    3811 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 417.1+ KB

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %%
data['Purchase Price'].avg()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9904\2591035373.py in ?()
# ----> 1 data['Purchase Price'].avg()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'avg'

# %%
data['Purchase Price'].mean()
# Out:
# 50.30394647074259

# %%
data.groupby('Language').count()
# Out:
#           Address  Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de            455  455       455           455      455          455
# el            407  407       407           407      407          407
# en            416  416       416           416      416          416
# es            425  425       425           425      425          425
# fr            453  453       453           453      453          453
# it            426  426       426           426      426          426
# pt            412  412       412           412      412          412
# ru            418  418       418           418      418          418
# zh            399  399       399           399      399          399
#
#           CC Exp Date  CC Security Code  CC Provider  Email  Job  IP Address  \
# Language
# de                455               455          455    455  455         455
# el                407               407          407    407  407         407
# ...

# %%
groupby('Language').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 groupby('Language').count()
#
# NameError: name 'groupby' is not defined

# %%
data['Lot'].groupby('Language').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data['Lot'].groupby('Language').count()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:2131, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2128     raise TypeError("as_index=False only valid with DataFrame")
#    2129 axis = self._get_axis_number(axis)
# -> 2131 return SeriesGroupBy(
#    2132     obj=self,
#    2133     keys=by,
#    2134     axis=axis,
#    2135     level=level,
#    2136     as_index=as_index,
#    2137     sort=sort,
#    2138     group_keys=group_keys,
#    2139     observed=observed,
#    2140     dropna=dropna,
#    2141 )
#
# ...

# %%
data.groupby('Language').count('Purchase Price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data.groupby('Language').count('Purchase Price')
#
# TypeError: GroupBy.count() takes 1 positional argument but 2 were given

# %%
data.groupby('Language').sum('Purchase Price')
# Out:
#                   Credit Card  CC Security Code  Purchase Price
# Language
# de        1070789982655623020            401073        23242.20
# el         917657885639883327            381998        20510.37
# en         958134451979808170            388675        20867.68
# es        1055054724966711282            400780        20844.44
# fr        1035841512507363045            377820        21862.10
# it        1017050892622361939            384114        21621.72
# pt         967937449491927323            334894        21325.22
# ru         969504867601387964            383850        21186.22
# zh         920222221772375506            313184        20248.39

# %%
data['Language'].groupby('Language').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data['Language'].groupby('Language').count()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:2131, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2128     raise TypeError("as_index=False only valid with DataFrame")
#    2129 axis = self._get_axis_number(axis)
# -> 2131 return SeriesGroupBy(
#    2132     obj=self,
#    2133     keys=by,
#    2134     axis=axis,
#    2135     level=level,
#    2136     as_index=as_index,
#    2137     sort=sort,
#    2138     group_keys=group_keys,
#    2139     observed=observed,
#    2140     dropna=dropna,
#    2141 )
#
# ...

# %%
data['Language'].value_counts().sort_values(ascending=False)
# Out:
# Language
# de    455
# fr    453
# it    426
# es    425
# ru    418
# en    416
# pt    412
# el    407
# zh    399
# Name: count, dtype: int64

# %%
# Out:
# Address             212
# Lot                 212
# AM or PM            212
# Browser Info        212
# Company             212
# Credit Card         212
# CC Exp Date         212
# CC Security Code    212
# CC Provider         212
# Email               212
# Job                 212
# IP Address          212
# Language            212
# Purchase Price      212
# dtype: int64

# %%
data['Job'].str.contains('engineer', case=False).value_counts()
# Out:
# Job
# False    3423
# True      389
# Name: count, dtype: int64

# %%
data[data['IP Address']=="132.207.160.22"]['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data[(data['CC Provider']=="Mastercard")&(data['Purchase Price']>50)].count()
# Out:
# Address             176
# Lot                 176
# AM or PM            176
# Browser Info        176
# Company             176
# Credit Card         176
# CC Exp Date         176
# CC Security Code    176
# CC Provider         176
# Email               176
# Job                 176
# IP Address          176
# Language            176
# Purchase Price      176
# dtype: int64

# %%
df.head()
# Out:
#                                               Address    Lot AM or PM  \
# 1   9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18  461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                   USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35  93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41  779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
#
#                                          Browser Info  \
# 1   Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 18  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 31  Opera/8.84.(X11; Linux i686; sl-SI) Presto/2.9...
# 35  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 41  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
#
#                             Company       Credit Card CC Exp Date  \
# 1   Fletcher, Richards and Whitaker  3337758169645356       11/18
# 18           Beard, Abbott and Pena  6011350184276270       12/22
# ...

# %%
df[df['Purchase Price']>50]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 3693  9422 Michael Loaf Apt. 258\nColinville, ID 207...  36 uV       AM
# 3741              Unit 6500 Box 8386\nDPO AP 56519-4129  10 oR       AM
# 3770  5145 Austin Shoals Suite 297\nLake William, NY...  01 vY       AM
# 3776           697 Mckee Row\nKatieville, DE 77945-1867  38 fB       AM
# 3789       559 Hahn Road Apt. 860\nAaronville, MP 30305  66 Ci       PM
#
#                                            Browser Info  \
# ...

# %%
def fun():
   lst=list()
   y=0
   g=0
   h=0
   for email in data['Email']:
      org=email.split('@')[1]
      domain=org.split('.')[0]
      lst.append(domain)
   for name in lst:
      if name=="yahoo":
         y=y+1
      elif name=="gmail":
         g=g+1
      elif name=="hotmail":
         h=h+1
      else:
         continue
   print("there are", y, "yahoo mails")
   print("there are", g, "gmail mails")
   print("there are", h, "hotmail mails")

# %%
fun()
# Out:
# there are 647 yahoo mails
# there are 585 gmail mails
# there are 635 hotmail mails

# %%
len(data[data['CC Exp Date'].apply(lambda x:x[3:]=='20')])
# Out:
# 361

# %%
list1=list()
for email in data['Email']:
   org=email.split('@')[1]
   domain=org.split('.')[0]
   list1.append(domain)

# %%
data['domain']=list1

# %%
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data.groupby(
# Out:
# 3812

# %%
data.groupby('Language').count()
# Out:
#           Address  Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de            455  455       455           455      455          455
# el            407  407       407           407      407          407
# en            416  416       416           416      416          416
# es            425  425       425           425      425          425
# fr            453  453       453           453      453          453
# it            426  426       426           426      426          426
# pt            412  412       412           412      412          412
# ru            418  418       418           418      418          418
# zh            399  399       399           399      399          399
#
#           CC Exp Date  CC Security Code  CC Provider  Email  Job  IP Address  \
# Language
# de                455               455          455    455  455         455
# el                407               407          407    407  407         407
# ...

# %%
data.groupby('domain').count()
# Out:
#                  Address  Lot  AM or PM  Browser Info  Company  Credit Card  \
# domain
# acevedo-pena           1    1         1             1        1            1
# adams                  6    6         6             6        6            6
# adams-garcia           1    1         1             1        1            1
# aguilar                4    4         4             4        4            4
# aguilar-nelson         1    1         1             1        1            1
# ...                  ...  ...       ...           ...      ...          ...
# young                  4    4         4             4        4            4
# young-cole             1    1         1             1        1            1
# zavala                 1    1         1             1        1            1
# zhang                  1    1         1             1        1            1
# zimmerman-clark        1    1         1             1        1            1
#
# ...

# %%
data["domain"].value_counts().sort_values(ascending=False)
# Out:
# domain
# yahoo              647
# hotmail            635
# gmail              585
# smith               27
# jones               20
#                   ...
# farmer-bates         1
# moore-bell           1
# smith-chavez         1
# hartman              1
# pineda-buchanan      1
# Name: count, Length: 1223, dtype: int64
